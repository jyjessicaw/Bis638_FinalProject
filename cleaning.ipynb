# %%
# DATA CLEANING
# import librarys
import pandas as pd
import sqlite3
from sqlite3 import Error
from IPython.display import display
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
""" create a database connection to a database that resides
    in the drive
"""
conn = None;
try:
  #conn = sqlite3.connect(':memory:')
  #replace the following file path with your own
  conn = sqlite3.connect('/content/gdrive/My Drive/mimic.db')
  cursor = conn.cursor()
  sql='''SELECT * from Admissions'''
  cursor.execute(sql)
  Admissions = pd.DataFrame(cursor.fetchall()).dropna()
  #Admissions.to_csv('admissions.csv')a
  sql1=''' SELECT * from Diagnoses_icd   '''
  cursor.execute(sql1)
  Diagnoses=pd.DataFrame(cursor.fetchall()).dropna()
  sql2='''SELECT * from D_icd_diagnoses  '''
  cursor.execute(sql2)
  icd=pd.DataFrame(cursor.fetchall()).dropna()
  sql3=''' SELECT * from Patients'''
  cursor.execute(sql3)
  patients=pd.DataFrame(cursor.fetchall()).dropna()
  sql4='''SELECT * from Prescriptions '''
  cursor.execute(sql4)
  prescriptions=pd.DataFrame(cursor.fetchall()).dropna()
  cursor.close()

  #  a=pd.read_sql(sql,conn)
  #  display(a)
  #  diagnoses = pd.read_csv('https://physionet.org/files/mimiciii-demo/1.4/DIAGNOSES_ICD.csv')
  #  icds = pd.read_csv('https://physionet.org/files/mimiciii-demo/1.4/D_ICD_DIAGNOSES.csv')



except Error as e:
    print(e)
finally:
    if conn:
        conn.close()

# %%
prescriptions
# Out:
#               0      1       2         3                    4   \
# 30       2122377     13  143045  263738.0  2167-01-09 00:00:00
# 31       2122379     13  143045  263738.0  2167-01-09 00:00:00
# 32       2122378     13  143045  263738.0  2167-01-09 00:00:00
# 33       2122376     13  143045  263738.0  2167-01-09 00:00:00
# 34       2122375     13  143045  263738.0  2167-01-09 00:00:00
# ...          ...    ...     ...       ...                  ...
# 4156445  3996662  98887  121032  238144.0  2144-09-06 00:00:00
# 4156446  3996070  98887  121032  238144.0  2144-09-06 00:00:00
# 4156447  3996063  98887  121032  238144.0  2144-09-06 00:00:00
# 4156448  3996062  98887  121032  238144.0  2144-09-06 00:00:00
# 4156449  3996061  98887  121032  238144.0  2144-09-06 00:00:00
#
#                           5     6                         7   \
# 30       2167-01-09 00:00:00  MAIN             Midazolam HCl
# 31       2167-01-09 00:00:00  MAIN          Nitroglycerin SL
# ...
